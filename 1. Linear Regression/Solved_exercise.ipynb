# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df = pd.read_csv('canada_per_capita_income.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
import matplotlib.pyplot as plt
plt.plot(df[['year']], df[['per capita income (US$)']])

# %%
lr = linear_model.LinearRegression()
lr.fit(df[['year']], df[['per capita income (US$)']])
# Out:
# LinearRegression()

# %%
plt.plot(df[['year']], df[['per capita income (US$)']])
plt.plot(df[['year']], lr.predict(df[['year']]), color='red')

# %%
lr.predict([[2020]])
# Out:
# C:\Users\vaibh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])

# %%
y_predicted = lr.predict(df[['year']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 y_predicted = lr.predict(y_test)
#
# NameError: name 'y_test' is not defined

# %%
from metrics import mean_squared_error, mean_absolute_error

mae = mean_absolute_error(lr.predict(df[['year']])
